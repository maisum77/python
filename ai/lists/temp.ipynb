# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import deque

# %%
graph={
    'A':['B','C'],
    'B':['A','D','E'],
    'C':['A','F'],
    'D':['B','G'],
    'E':['B','G'],
    'F':['C','G'],
    'G':['D','E','F']
}

# %%
def bfs(graph,start,goal):
    visited={start}
    queue=deque([[start]])
    while queue:
        path=queue.popleft()
        node=path[-1]
        if node==goal:
            return path
        for i in graph[node]:
            if i not in visited:
                visited.add(i)
                new_state=path+[i]
                queue.append(new_state)
    return None

# %%
dfs(Graph,'A','G')
# Out:
# ['A', 'B', 'D', 'G']

# %%
def DFS(graph,start,goal,visited=None,path=None):
    if visited == None:
        visited=set()
        path=[]
    if start not in visited:
        visited.add(start)
        path.append(start)
    if start == goal:
        return path
    for i in graph[start]:
        if i not in visited:
            return DFS(graph,i,goal,visited,path)

# %%
DFS(graph,'A','G')
# Out:
# ['A', 'B', 'D', 'G']

# %%
Graph={
    'A':['B','C'],
    'B':['A','D','E'],
    'C':['A','F'],
    'D':['B','G'],
    'E':['B','G'],
    'F':['C','G'],
    'G':['D','E','F']
}
diagram=nx.Graph()
diagram.add_edges_from([('A','B'),('A','C'),('B','A'),('B','D'),('B','E'),('C','A'),('C','F'),('D','B'),('D','G'),('E','B'),('E','G'),('F','C'),('F','G'),('G','D'),('G','E'),('G','F')])
nx.draw(diagram,with_labels=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 10
#       1 Graph={
#       2     'A':['B','C'],
#       3     'B':['A','D','E'],
#    (...)
#       8     'G':['D','E','F']
#       9 }
# ---> 10 diagram=nx.Graph()
#      11 diagram.add_edges_from([('A','B'),('A','C'),('B','A'),('B','D'),('B','E'),('C','A'),('C','F'),('D','B'),('D','G'),('E','B'),('E','G'),('F','C'),('F','G'),('G','D'),('G','E'),('G','F')])
#      12 nx.draw(diagram,with_labels=True)
#
# TypeError: 'dict' object is not callable

# %%
a=int(input("Enter a number= "))

def even(a):
    if a%2==0:
        print("even number")
    else:
        print("odd number")

even(a)
# Out:
# even number

# %%
list=[1,2,3,"helllooo","umair"]
list.insert(1234)
print(list)
# Out:
# [1, 2, 3, 'helllooo', 'umair', 1234]

# %%
list=[[1,2,3],1,2,3]
print(list)
# Out:
# [[1, 2, 3], 1, 2, 3]

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
g=n.Graph()
g.add_edges_from([('A','B'),('A','C'),('B','C')])
n.draw(g,with_labels=True)
plt.show()

# %%
diagram=nx.Graph()
diagram.add_edges_from([('A','B'),('A','C'),('B','A'),('B','D'),('B','E'),('C','A'),('C','F'),('D','B'),('D','G'),('E','B'),('E','G'),('F','C'),('F','G'),('G','D'),('G','E'),('G','F')])
nx.draw(diagram,with_labels=True)
plt.show()

# %%
graph={
    'A':['B','C'],
    'B':['A','D','E'],
    'C':['A','F'],
    'D':['B','G'],
    'E':['B','G'],
    'F':['C','G'],
    'G':['D','E','F']
}

# %%
dia=nx.Graph(graph)
nx.draw(dia,with_labels=True)
plt.draw()
